# %%
# Load raw features
import pandas as pd
raw_df = pd.read_csv('../data/raw/features.csv')
raw_df.head()

# %%
# Simple stats
raw_df.describe()

# %%
# Placeholder model info via service layer (requires package context)
from app.services.model import get_model
get_model()
