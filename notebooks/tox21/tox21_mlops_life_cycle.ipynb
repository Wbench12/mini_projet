# %%
# !wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# wandb: Currently logged in as: l-benhammadi (l-benhammadi-esi) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Phase 1: Data Ingestion & Preparation
#
# In this phase, we prepare the **Tox21 toxicity dataset** and **ZINC unlabeled molecular dataset** for Semi-Supervised Learning (SSL).
#
# ### What We Do:
# 1. **Load Raw Data**: Import Tox21 labeled toxicity data and ZINC unlabeled molecular structures
# 2. **Canonicalize SMILES**: Standardize molecular representations using RDKit
# 3. **Feature Engineering**: Compute comprehensive molecular descriptors:
#    - Basic properties (MolWt, LogP, H-donors/acceptors)
#    - Lipinski's Rule of Five features
#    - Topological descriptors (BertzCT, Kappa indices)
#    - Pharmacophore features
# 4. **Handle Class Imbalance**: Downsample majority class for balanced training
# 5. **Version with W&B**: Create artifacts for data reproducibility
#
# ### Datasets:
# - **Tox21**: ~7,800 compounds across 12 toxicity assays
# - **ZINC**: Large unlabeled molecular database
# - **Target**: Binary classification (toxic vs non-toxic)

# %%
import wandb
from rdkit import Chem
from rdkit.Chem import Descriptors, QED, Lipinski, Crippen, MolSurf, rdMolDescriptors
import pandas as pd
import numpy as np
from sklearn.utils import resample

PROJECT="QSAR_MLOPS_TOX21"

run = wandb.init(project=PROJECT, job_type="prepare-data")
raw_df_unlabeled = pd.read_csv('../../data/raw/original_data/zinc_unlabeled.csv')
raw_df_labeled = pd.read_csv('../../data/raw/original_data/tox21.csv')

def canonicalize_smiles(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles.strip())
        if mol is not None:
            return Chem.MolToSmiles(mol, canonical=True)
    except:
        pass
    return None

def compute_comprehensive_features(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles.strip())
        if mol is not None:
            features = {}
            
            # Basic molecrun.finish()ular properties
            features['MolWt'] = Descriptors.MolWt(mol)
            features['LogP'] = Descriptors.MolLogP(mol)
            features['NumHDonors'] = Descriptors.NumHDonors(mol)
            features['NumHAcceptors'] = Descriptors.NumHAcceptors(mol)
            features['NumRotatableBonds'] = Descriptors.NumRotatableBonds(mol)
            features['NumAromaticRings'] = Descriptors.NumAromaticRings(mol)
            
            # Lipinski's Rule of Five
            features['NumHeteroatoms'] = Descriptors.NumHeteroatoms(mol)
            features['TPSA'] = Descriptors.TPSA(mol)
            
            # Complexity and shape
            features['NumRings'] = Descriptors.RingCount(mol)
            features['NumAliphaticRings'] = Descriptors.NumAliphaticRings(mol)
            features['NumSaturatedRings'] = Descriptors.NumSaturatedRings(mol)
            features['FractionCsp3'] = Descriptors.FractionCSP3(mol) 
            
            # Electronic properties
            features['NumValenceElectrons'] = Descriptors.NumValenceElectrons(mol)
            
            try:
                features['MaxPartialCharge'] = Descriptors.MaxPartialCharge(mol)
                features['MinPartialCharge'] = Descriptors.MinPartialCharge(mol)
            except:
                features['MaxPartialCharge'] = 0
                features['MinPartialCharge'] = 0
            
            # Molecular surface area
            features['LabuteASA'] = Descriptors.LabuteASA(mol)
            features['PEOE_VSA1'] = Descriptors.PEOE_VSA1(mol)
            features['PEOE_VSA2'] = Descriptors.PEOE_VSA2(mol)
            
            # Drug-likeness scores
            features['QED'] = QED.qed(mol)
            
            # Topological descriptors
            features['BertzCT'] = Descriptors.BertzCT(mol)
            features['Chi0v'] = Descriptors.Chi0v(mol)
            features['Chi1v'] = Descriptors.Chi1v(mol)
            features['Kappa1'] = Descriptors.Kappa1(mol)
            features['Kappa2'] = Descriptors.Kappa2(mol)
            
            # Additional descriptors
            features['MolMR'] = Descriptors.MolMR(mol)
            features['BalabanJ'] = Descriptors.BalabanJ(mol)
            features['HallKierAlpha'] = Descriptors.HallKierAlpha(mol)
            features['NumSaturatedCarbocycles'] = Descriptors.NumSaturatedCarbocycles(mol)
            features['NumAromaticCarbocycles'] = Descriptors.NumAromaticCarbocycles(mol)
            features['NumSaturatedHeterocycles'] = Descriptors.NumSaturatedHeterocycles(mol)
            features['NumAromaticHeterocycles'] = Descriptors.NumAromaticHeterocycles(mol)
            
            # Pharmacophore features
            features['fr_NH2'] = Descriptors.fr_NH2(mol)
            features['fr_COO'] = Descriptors.fr_COO(mol)
            features['fr_benzene'] = Descriptors.fr_benzene(mol)
            features['fr_furan'] = Descriptors.fr_furan(mol)
            features['fr_halogen'] = Descriptors.fr_halogen(mol)
            
            return pd.Series(features)
    except Exception as e:
        print(f"Error computing features: {e}") 
        pass
    return pd.Series()

raw_df_labeled['canonical_smiles'] = raw_df_labeled['smiles'].apply(canonicalize_smiles)
raw_df_labeled = raw_df_labeled.dropna(subset=['canonical_smiles'])

tox_columns = ['NR-AR', 'NR-AR-LBD', 'NR-AhR', 'NR-Aromatase', 'NR-ER', 'NR-ER-LBD', 
               'NR-PPAR-gamma', 'SR-ARE', 'SR-ATAD5', 'SR-HSE', 'SR-MMP', 'SR-p53']

raw_df_labeled['toxic'] = raw_df_labeled[tox_columns].max(axis=1)

raw_df_labeled = raw_df_labeled.dropna(subset=['toxic'])

raw_df_labeled['toxic'] = raw_df_labeled['toxic'].astype(int)

raw_df_labeled = raw_df_labeled.drop(columns=tox_columns)

toxic_count = (raw_df_labeled['toxic'] == 1).sum()
non_toxic_count = (raw_df_labeled['toxic'] == 0).sum()


toxic_df = raw_df_labeled[raw_df_labeled['toxic'] == 1]
non_toxic_df = raw_df_labeled[raw_df_labeled['toxic'] == 0]

non_toxic_downsampled = resample(non_toxic_df, 
                                  replace=False,
                                  n_samples=len(toxic_df),
                                  random_state=42)

raw_df_labeled_balanced = pd.concat([toxic_df, non_toxic_downsampled])
raw_df_labeled_balanced = raw_df_labeled_balanced.sample(frac=1, random_state=42).reset_index(drop=True)


labeled_features = raw_df_labeled_balanced['canonical_smiles'].apply(compute_comprehensive_features)
all_labeled_with_features = pd.concat([raw_df_labeled_balanced, labeled_features], axis=1)
all_labeled_with_features = all_labeled_with_features.dropna()

all_labeled_with_features.to_csv('../../data/raw/enhanced_data/tox21/labeled_features.csv', index=False)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# wandb: Currently logged in as: l-benhammadi (l-benhammadi-esi) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_165547-a3b1lwg3</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a3b1lwg3' target="_blank">splendid-pond-1</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a3b1lwg3' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a3b1lwg3</a>
# [16:55:49] WARNING: not removing hydrogen atom without neighbors
# [16:55:49] Explicit valence for atom # 8 Al, 6, is greater than permitted
# [16:55:50] Explicit valence for atom # 3 Al, 6, is greater than permitted
# [16:55:50] Explicit valence for atom # 4 Al, 6, is greater than permitted
# [16:55:50] Explicit valence for atom # 4 Al, 6, is greater than permitted
# [16:55:50] Explicit valence for atom # 9 Al, 6, is greater than permitted
# [16:55:50] Explicit valence for atom # 5 Al, 6, is greater than permitted
# [16:55:50] Explicit valence for atom # 16 Al, 6, is greater than permitted
# [16:55:51] Explicit valence for atom # 20 Al, 6, is greater than permitted
# [16:55:58] WARNING: not removing hydrogen atom without neighbors
# [16:55:58] WARNING: not removing hydrogen atom without neighbors

# %%
raw_df_unlabeled['canonical_smiles'] = raw_df_unlabeled['smiles'].apply(canonicalize_smiles)
raw_df_unlabeled = raw_df_unlabeled.dropna(subset=['canonical_smiles'])

unlabeled_features = raw_df_unlabeled['canonical_smiles'].apply(compute_comprehensive_features)
unlabeled_with_features = pd.concat([raw_df_unlabeled[['smiles', 'canonical_smiles']], unlabeled_features], axis=1)
unlabeled_with_features['toxic'] = np.nan
unlabeled_with_features = unlabeled_with_features.dropna(subset=unlabeled_features.columns.tolist())

unlabeled_with_features.to_csv('../../data/raw/enhanced_data/tox21/unlabeled_features.csv', index=False)

# %%
exclude_cols = ['smiles', 'canonical_smiles', 'FDA_APPROVED', 'toxic','mol_id']
all_features = [col for col in all_labeled_with_features.columns if col not in exclude_cols]

X_labeled = all_labeled_with_features[all_features]
y_tox = all_labeled_with_features['toxic']

X_unlabeled = unlabeled_with_features[all_features]

# %%
def clip_outliers(df, std_threshold=3):
    """Clip outliers using standard deviation method"""
    df_clipped = df.copy()
    outlier_count = 0
    
    for col in df.columns:
        mean = df[col].mean()
        std = df[col].std()
        lower_bound = mean - std_threshold * std
        upper_bound = mean + std_threshold * std
        
        # Count outliers
        outliers = ((df[col] < lower_bound) | (df[col] > upper_bound)).sum()
        if outliers > 0:
            outlier_count += outliers
            print(f"  {col:20s}: {outliers} outliers clipped")
            df_clipped[col] = df[col].clip(lower_bound, upper_bound)
    
    return df_clipped, outlier_count

X_labeled_clipped, labeled_outliers = clip_outliers(X_labeled, std_threshold=3)
X_unlabeled_clipped, unlabeled_outliers = clip_outliers(X_unlabeled, std_threshold=3)
# Out:
#   MolWt               : 102 outliers clipped
#   LogP                : 80 outliers clipped
#   NumHDonors          : 93 outliers clipped
#   NumHAcceptors       : 102 outliers clipped
#   NumRotatableBonds   : 110 outliers clipped
#   NumAromaticRings    : 45 outliers clipped
#   NumHeteroatoms      : 75 outliers clipped
#   TPSA                : 83 outliers clipped
#   NumRings            : 78 outliers clipped
#   NumAliphaticRings   : 101 outliers clipped
#   NumSaturatedRings   : 104 outliers clipped
#   NumValenceElectrons : 99 outliers clipped
#   MinPartialCharge    : 14 outliers clipped
#   LabuteASA           : 97 outliers clipped
#   PEOE_VSA1           : 115 outliers clipped
#   PEOE_VSA2           : 70 outliers clipped
#   BertzCT             : 76 outliers clipped
#   Chi0v               : 103 outliers clipped
#   Chi1v               : 101 outliers clipped
#   Kappa1              : 100 outliers clipped
#   Kappa2              : 1 outliers clipped
#   MolMR               : 97 outliers clipped
#   BalabanJ            : 30 outliers clipped
#   HallKierAlpha       : 52 outliers clipped
#   NumSaturatedCarbocycles: 203 outliers clipped
#   NumAromaticCarbocycles: 74 outliers clipped
#   NumSaturatedHeterocycles: 106 outliers clipped
#   NumAromaticHeterocycles: 258 outliers clipped
#   fr_NH2              : 182 outliers clipped
#   fr_COO              : 136 outliers clipped
#   fr_benzene          : 74 outliers clipped
#   fr_furan            : 66 outliers clipped
#   fr_halogen          : 94 outliers clipped
#   LogP                : 1543 outliers clipped
#   NumHDonors          : 2089 outliers clipped
#   NumHAcceptors       : 1502 outliers clipped
#   NumRotatableBonds   : 3 outliers clipped
#   NumAromaticRings    : 888 outliers clipped
#   NumHeteroatoms      : 645 outliers clipped
#   TPSA                : 688 outliers clipped
#   NumRings            : 1386 outliers clipped
#   NumAliphaticRings   : 1896 outliers clipped
#   NumSaturatedRings   : 1155 outliers clipped
#   NumValenceElectrons : 411 outliers clipped
#   MaxPartialCharge    : 717 outliers clipped
#   MinPartialCharge    : 3890 outliers clipped
#   LabuteASA           : 154 outliers clipped
#   PEOE_VSA1           : 977 outliers clipped
#   PEOE_VSA2           : 2397 outliers clipped
#   QED                 : 1634 outliers clipped
#   BertzCT             : 885 outliers clipped
#   Chi0v               : 444 outliers clipped
#   Chi1v               : 738 outliers clipped
#   Kappa1              : 568 outliers clipped
#   Kappa2              : 723 outliers clipped
#   MolMR               : 408 outliers clipped
#   BalabanJ            : 2909 outliers clipped
#   HallKierAlpha       : 231 outliers clipped
#   NumSaturatedCarbocycles: 4963 outliers clipped
#   NumAromaticCarbocycles: 53 outliers clipped
#   NumSaturatedHeterocycles: 1566 outliers clipped
#   NumAromaticHeterocycles: 526 outliers clipped
#   fr_NH2              : 1287 outliers clipped
#   fr_COO              : 9355 outliers clipped
#   fr_benzene          : 52 outliers clipped
#   fr_furan            : 12581 outliers clipped
#   fr_halogen          : 2910 outliers clipped

# %%
df_labeled_processed = X_labeled_clipped.copy()

df_labeled_processed['toxic'] = y_tox.values

df_unlabeled_processed = X_unlabeled_clipped.copy()
df_unlabeled_processed['toxic'] = np.nan

df_labeled_processed.to_csv('../../data/processed/tox21/labeled_processed.csv', index=False)
df_unlabeled_processed.to_csv('../../data/processed/tox21/unlabeled_processed.csv', index=False)

# %%
artifact_tox21_labeled   = wandb.Artifact(
            name="tox21-labeled-dataset",
            type="dataset",
            description="Cleaned labeled tox21 data for v1.0" 
            )
artifact_tox21_labeled.add_file('../../data/processed/tox21/labeled_processed.csv')

run.log_artifact(artifact_tox21_labeled)
# Out:
# <Artifact tox21-labeled-dataset>

# %%
artifact_zinc_unlabeled   = wandb.Artifact(
            name="zinc-unlabeled-dataset",
            type="dataset",
            description="Cleaned unlabeled zinc data for v1.0" 
            )
artifact_zinc_unlabeled.add_file('../../data/processed/tox21/unlabeled_processed.csv')
run.log_artifact(artifact_zinc_unlabeled)
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">splendid-pond-1</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a3b1lwg3' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a3b1lwg3</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_165547-a3b1lwg3/logs</code>

# %% [markdown]
# ## Phase 2 & 3: Baseline Model & Hyperparameter Optimization
#
# We establish a **baseline supervised model** using Random Forest, then optimize hyperparameters with W&B Sweeps.
#
# ### Approach:
# 1. **Baseline Training**: Train Random Forest on labeled data only
# 2. **Bayesian Optimization**: Systematically search hyperparameter space
# 3. **Metrics Tracked**: F1-Score, ROC-AUC, Precision, Recall, Accuracy
# 4. **Model Registry**: Save best baseline model as W&B artifact
#
# ### Hyperparameters Tuned:
# - `n_estimators`: Number of trees (50-200)
# - `max_depth`: Tree depth (10-30)
# - `min_samples_split`: Split threshold (2, 5, 10)
# - `min_samples_leaf`: Leaf size (1, 2, 4)
# - `max_features`: Feature sampling ('sqrt', 'log2')
#
# This baseline serves as the benchmark for our Semi-Supervised Learning methods.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

wandb.init(project=PROJECT, job_type="experiment")

run = wandb.use_artifact('zinc-unlabeled-dataset:latest')
data_path = run.download()
df_unlabeled = pd.read_csv(f"{data_path}/unlabeled_processed.csv")

run= wandb.use_artifact('tox21-labeled-dataset:latest')
data_path = run.download()
df_labeled = pd.read_csv(f"{data_path}/labeled_processed.csv")
# Out:
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171335-2buia4hs</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2buia4hs' target="_blank">generous-wood-2</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2buia4hs' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2buia4hs</a>
# wandb: Downloading large artifact 'zinc-unlabeled-dataset:latest', 92.69MB. 1 files...
# wandb:   1 of 1 files downloaded.
# Done. 00:00:01.1 (83.4MB/s)
# wandb:   1 of 1 files downloaded.
# Exception in thread ChkStopThr:
# Traceback (most recent call last):
#   File "/home/lokmane/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/lokmane/anaconda3/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py", line 309, in check_stop_status
#     self._loop_check_status(
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_run.py", line 237, in _loop_check_status
#     local_handle = request()
#                    ^^^^^^^^^
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py", line 985, in deliver_stop_status
#     return self._deliver_stop_status(status)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py", line 480, in _deliver_stop_status
#     return self._deliver(record)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py", line 50, in _deliver
#     return self._asyncer.run(lambda: self.deliver_async(record))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py", line 133, in run
#     future = self._schedule(fn, daemon=False)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lokmane/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py", line 198, in _schedule
#     raise AlreadyJoinedError
# wandb.sdk.lib.asyncio_manager.AlreadyJoinedError

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

X = df_labeled.drop('toxic', axis=1)
y = df_labeled['toxic']

X = X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(X.median())

print(f"NaN values: {X.isna().sum().sum()}")
print(f"Inf values: {np.isinf(X.values).sum()}")

X_unlabeled_full = df_unlabeled.drop('toxic', axis=1)
X_unlabeled_full = X_unlabeled_full.replace([np.inf, -np.inf], np.nan)
X_unlabeled_full = X_unlabeled_full.fillna(X_unlabeled_full.median())

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print("\nScaling features...")
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_unlabeled_scaled = scaler.transform(X_unlabeled_full)

X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
X_unlabeled_full = X_unlabeled_scaled
# Out:
# NaN values: 0
# Inf values: 0
#
# Scaling features...

# %%
baseline_sweep_config = {
    'method': 'bayes',
    'metric': {'name': 'val_f1', 'goal': 'maximize'},
    'parameters': {
        'n_estimators': {'values': [50, 100, 150, 200]},
        'max_depth': {'values': [10, 15, 20, 25, 30]},
        'min_samples_split': {'values': [2, 5, 10]},
        'min_samples_leaf': {'values': [1, 2, 4]},
        'max_features': {'values': ['sqrt', 'log2']}
    }
}

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

def train_baseline():
    run = wandb.init()
    config = wandb.config
    
    model = RandomForestClassifier(
        n_estimators=config.n_estimators,
        max_depth=config.max_depth,
        min_samples_split=config.min_samples_split,
        min_samples_leaf=config.min_samples_leaf,
        max_features=config.max_features,
        random_state=42,
        n_jobs=-1,
        class_weight='balanced'
    )
    
    model.fit(X_train.values, y_train.values)
    
    y_pred = model.predict(X_test.values)
    y_pred_proba = model.predict_proba(X_test.values)[:, 1]
    
    metrics = {
        'val_accuracy': accuracy_score(y_test, y_pred),
        'val_precision': precision_score(y_test, y_pred, zero_division=0),
        'val_recall': recall_score(y_test, y_pred, zero_division=0),
        'val_f1': f1_score(y_test, y_pred, zero_division=0),
        'val_roc_auc': roc_auc_score(y_test, y_pred_proba)
    }
    
    wandb.log(metrics)
    
    print(f"F1: {metrics['val_f1']:.4f}, ROC-AUC: {metrics['val_roc_auc']:.4f}")

print("✓ Baseline training function defined")
# Out:
# ✓ Baseline training function defined

# %%
baseline_sweep_id = wandb.sweep(baseline_sweep_config, project=PROJECT)
wandb.agent(baseline_sweep_id, train_baseline, count=20)

print("✓ Baseline sweep completed!")
# Out:
# Create sweep with ID: i87xe0rl
# Sweep URL: https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl
# wandb: Agent Starting Run: eq1f7mjp with config:
# wandb: 	max_depth: 30
# wandb: 	max_features: sqrt
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 200
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# wandb:
# wandb: 🚀 View run generous-wood-2 at: https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2buia4hs
# wandb: Find logs at: wandb/run-20260124_171335-2buia4hs/logs
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171347-eq1f7mjp</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eq1f7mjp' target="_blank">astral-sweep-1</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eq1f7mjp' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eq1f7mjp</a>
# F1: 0.6754, ROC-AUC: 0.7591
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69394</td></tr><tr><td>val_f1</td><td>0.67541</td></tr><tr><td>val_precision</td><td>0.71466</td></tr><tr><td>val_recall</td><td>0.64024</td></tr><tr><td>val_roc_auc</td><td>0.75913</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">astral-sweep-1</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eq1f7mjp' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eq1f7mjp</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171347-eq1f7mjp/logs</code>
# wandb: Agent Starting Run: xtha52bs with config:
# wandb: 	max_depth: 10
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 150
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171351-xtha52bs</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xtha52bs' target="_blank">eager-sweep-2</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xtha52bs' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xtha52bs</a>
# F1: 0.6675, ROC-AUC: 0.7646
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.68511</td></tr><tr><td>val_f1</td><td>0.6675</td></tr><tr><td>val_precision</td><td>0.70288</td></tr><tr><td>val_recall</td><td>0.6355</td></tr><tr><td>val_roc_auc</td><td>0.76465</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-sweep-2</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xtha52bs' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xtha52bs</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171351-xtha52bs/logs</code>
# wandb: Agent Starting Run: a7ybgifm with config:
# wandb: 	max_depth: 20
# wandb: 	max_features: sqrt
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 50
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171357-a7ybgifm</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a7ybgifm' target="_blank">olive-sweep-3</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a7ybgifm' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a7ybgifm</a>
# F1: 0.6874, ROC-AUC: 0.7620
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70394</td></tr><tr><td>val_f1</td><td>0.68738</td></tr><tr><td>val_precision</td><td>0.72382</td></tr><tr><td>val_recall</td><td>0.65444</td></tr><tr><td>val_roc_auc</td><td>0.76199</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">olive-sweep-3</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a7ybgifm' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/a7ybgifm</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171357-a7ybgifm/logs</code>
# wandb: Agent Starting Run: ppeeammi with config:
# wandb: 	max_depth: 10
# wandb: 	max_features: sqrt
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 150
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171403-ppeeammi</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ppeeammi' target="_blank">charmed-sweep-4</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ppeeammi' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ppeeammi</a>
# F1: 0.6878, ROC-AUC: 0.7684
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70453</td></tr><tr><td>val_f1</td><td>0.68781</td></tr><tr><td>val_precision</td><td>0.72477</td></tr><tr><td>val_recall</td><td>0.65444</td></tr><tr><td>val_roc_auc</td><td>0.76843</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">charmed-sweep-4</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ppeeammi' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ppeeammi</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171403-ppeeammi/logs</code>
# wandb: Agent Starting Run: xe55gqzq with config:
# wandb: 	max_depth: 10
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 150
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171408-xe55gqzq</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xe55gqzq' target="_blank">colorful-sweep-5</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xe55gqzq' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xe55gqzq</a>
# F1: 0.6741, ROC-AUC: 0.7664
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.68864</td></tr><tr><td>val_f1</td><td>0.67406</td></tr><tr><td>val_precision</td><td>0.70308</td></tr><tr><td>val_recall</td><td>0.64734</td></tr><tr><td>val_roc_auc</td><td>0.76642</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">colorful-sweep-5</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xe55gqzq' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xe55gqzq</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171408-xe55gqzq/logs</code>
# wandb: Agent Starting Run: qa1raas2 with config:
# wandb: 	max_depth: 20
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 100
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171414-qa1raas2</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/qa1raas2' target="_blank">absurd-sweep-6</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/qa1raas2' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/qa1raas2</a>
# F1: 0.6787, ROC-AUC: 0.7617
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.6957</td></tr><tr><td>val_f1</td><td>0.67868</td></tr><tr><td>val_precision</td><td>0.71466</td></tr><tr><td>val_recall</td><td>0.64615</td></tr><tr><td>val_roc_auc</td><td>0.7617</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">absurd-sweep-6</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/qa1raas2' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/qa1raas2</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171414-qa1raas2/logs</code>
# wandb: Agent Starting Run: ed91ukw9 with config:
# wandb: 	max_depth: 10
# wandb: 	max_features: sqrt
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 200
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171420-ed91ukw9</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ed91ukw9' target="_blank">exalted-sweep-7</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ed91ukw9' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ed91ukw9</a>
# F1: 0.6783, ROC-AUC: 0.7680
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69511</td></tr><tr><td>val_f1</td><td>0.67826</td></tr><tr><td>val_precision</td><td>0.71373</td></tr><tr><td>val_recall</td><td>0.64615</td></tr><tr><td>val_roc_auc</td><td>0.76795</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exalted-sweep-7</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ed91ukw9' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ed91ukw9</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171420-ed91ukw9/logs</code>
# wandb: Agent Starting Run: sfivvejh with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 200
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171426-sfivvejh</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sfivvejh' target="_blank">logical-sweep-8</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sfivvejh' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sfivvejh</a>
# F1: 0.6791, ROC-AUC: 0.7646
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69629</td></tr><tr><td>val_f1</td><td>0.6791</td></tr><tr><td>val_precision</td><td>0.7156</td></tr><tr><td>val_recall</td><td>0.64615</td></tr><tr><td>val_roc_auc</td><td>0.76456</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">logical-sweep-8</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sfivvejh' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sfivvejh</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171426-sfivvejh/logs</code>
# wandb: Agent Starting Run: 85ntbr7r with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: sqrt
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 100
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171431-85ntbr7r</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/85ntbr7r' target="_blank">hearty-sweep-9</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/85ntbr7r' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/85ntbr7r</a>
# F1: 0.6787, ROC-AUC: 0.7605
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69688</td></tr><tr><td>val_f1</td><td>0.67873</td></tr><tr><td>val_precision</td><td>0.71768</td></tr><tr><td>val_recall</td><td>0.64379</td></tr><tr><td>val_roc_auc</td><td>0.76048</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hearty-sweep-9</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/85ntbr7r' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/85ntbr7r</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171431-85ntbr7r/logs</code>
# wandb: Agent Starting Run: q5o6nws2 with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 200
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171437-q5o6nws2</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/q5o6nws2' target="_blank">fresh-sweep-10</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/q5o6nws2' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/q5o6nws2</a>
# F1: 0.6804, ROC-AUC: 0.7669
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69865</td></tr><tr><td>val_f1</td><td>0.6804</td></tr><tr><td>val_precision</td><td>0.71995</td></tr><tr><td>val_recall</td><td>0.64497</td></tr><tr><td>val_roc_auc</td><td>0.76692</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fresh-sweep-10</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/q5o6nws2' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/q5o6nws2</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171437-q5o6nws2/logs</code>
# wandb: Agent Starting Run: 1n8t22tv with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 150
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171443-1n8t22tv</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1n8t22tv' target="_blank">warm-sweep-11</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1n8t22tv' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1n8t22tv</a>
# F1: 0.6766, ROC-AUC: 0.7607
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69394</td></tr><tr><td>val_f1</td><td>0.67662</td></tr><tr><td>val_precision</td><td>0.71298</td></tr><tr><td>val_recall</td><td>0.64379</td></tr><tr><td>val_roc_auc</td><td>0.76071</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">warm-sweep-11</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1n8t22tv' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1n8t22tv</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171443-1n8t22tv/logs</code>
# wandb: Agent Starting Run: iu3mjuaj with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 50
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171448-iu3mjuaj</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/iu3mjuaj' target="_blank">fast-sweep-12</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/iu3mjuaj' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/iu3mjuaj</a>
# F1: 0.6840, ROC-AUC: 0.7681
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70041</td></tr><tr><td>val_f1</td><td>0.68405</td></tr><tr><td>val_precision</td><td>0.71932</td></tr><tr><td>val_recall</td><td>0.65207</td></tr><tr><td>val_roc_auc</td><td>0.76812</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fast-sweep-12</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/iu3mjuaj' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/iu3mjuaj</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171448-iu3mjuaj/logs</code>
# wandb: Agent Starting Run: 2ayjs8tw with config:
# wandb: 	max_depth: 20
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 200
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171454-2ayjs8tw</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2ayjs8tw' target="_blank">fearless-sweep-13</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2ayjs8tw' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2ayjs8tw</a>
# F1: 0.6796, ROC-AUC: 0.7671
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69747</td></tr><tr><td>val_f1</td><td>0.67955</td></tr><tr><td>val_precision</td><td>0.71805</td></tr><tr><td>val_recall</td><td>0.64497</td></tr><tr><td>val_roc_auc</td><td>0.76709</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fearless-sweep-13</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2ayjs8tw' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/2ayjs8tw</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171454-2ayjs8tw/logs</code>
# wandb: Agent Starting Run: s74bbg8d with config:
# wandb: 	max_depth: 20
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 50
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171500-s74bbg8d</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/s74bbg8d' target="_blank">quiet-sweep-14</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/s74bbg8d' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/s74bbg8d</a>
# F1: 0.6943, ROC-AUC: 0.7694
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70865</td></tr><tr><td>val_f1</td><td>0.69426</td></tr><tr><td>val_precision</td><td>0.7261</td></tr><tr><td>val_recall</td><td>0.66509</td></tr><tr><td>val_roc_auc</td><td>0.76936</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">quiet-sweep-14</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/s74bbg8d' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/s74bbg8d</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171500-s74bbg8d/logs</code>
# wandb: Agent Starting Run: t1bsh028 with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 100
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171505-t1bsh028</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/t1bsh028' target="_blank">generous-sweep-15</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/t1bsh028' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/t1bsh028</a>
# F1: 0.6830, ROC-AUC: 0.7654
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70218</td></tr><tr><td>val_f1</td><td>0.68296</td></tr><tr><td>val_precision</td><td>0.7257</td></tr><tr><td>val_recall</td><td>0.64497</td></tr><tr><td>val_roc_auc</td><td>0.76536</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">generous-sweep-15</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/t1bsh028' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/t1bsh028</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171505-t1bsh028/logs</code>
# wandb: Agent Starting Run: sn8dk5xx with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 5
# wandb: 	n_estimators: 50
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171511-sn8dk5xx</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sn8dk5xx' target="_blank">robust-sweep-16</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sn8dk5xx' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sn8dk5xx</a>
# F1: 0.6840, ROC-AUC: 0.7681
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70041</td></tr><tr><td>val_f1</td><td>0.68405</td></tr><tr><td>val_precision</td><td>0.71932</td></tr><tr><td>val_recall</td><td>0.65207</td></tr><tr><td>val_roc_auc</td><td>0.76812</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">robust-sweep-16</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sn8dk5xx' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/sn8dk5xx</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171511-sn8dk5xx/logs</code>
# wandb: Agent Starting Run: eue1fkve with config:
# wandb: 	max_depth: 20
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 50
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171517-eue1fkve</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eue1fkve' target="_blank">giddy-sweep-17</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eue1fkve' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eue1fkve</a>
# F1: 0.6737, ROC-AUC: 0.7623
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69217</td></tr><tr><td>val_f1</td><td>0.67374</td></tr><tr><td>val_precision</td><td>0.7124</td></tr><tr><td>val_recall</td><td>0.63905</td></tr><tr><td>val_roc_auc</td><td>0.76229</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">giddy-sweep-17</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eue1fkve' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/eue1fkve</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171517-eue1fkve/logs</code>
# wandb: Agent Starting Run: uqwayukl with config:
# wandb: 	max_depth: 30
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 150
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171523-uqwayukl</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/uqwayukl' target="_blank">rose-sweep-18</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/uqwayukl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/uqwayukl</a>
# F1: 0.6704, ROC-AUC: 0.7583
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.69041</td></tr><tr><td>val_f1</td><td>0.67043</td></tr><tr><td>val_precision</td><td>0.71238</td></tr><tr><td>val_recall</td><td>0.63314</td></tr><tr><td>val_roc_auc</td><td>0.75832</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rose-sweep-18</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/uqwayukl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/uqwayukl</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171523-uqwayukl/logs</code>
# wandb: Agent Starting Run: xd0g52c5 with config:
# wandb: 	max_depth: 20
# wandb: 	max_features: log2
# wandb: 	min_samples_leaf: 4
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 100
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171529-xd0g52c5</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xd0g52c5' target="_blank">dazzling-sweep-19</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xd0g52c5' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xd0g52c5</a>
# F1: 0.6825, ROC-AUC: 0.7667
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70041</td></tr><tr><td>val_f1</td><td>0.68247</td></tr><tr><td>val_precision</td><td>0.72164</td></tr><tr><td>val_recall</td><td>0.64734</td></tr><tr><td>val_roc_auc</td><td>0.7667</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dazzling-sweep-19</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xd0g52c5' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/xd0g52c5</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171529-xd0g52c5/logs</code>
# wandb: Agent Starting Run: 6g9zqcgh with config:
# wandb: 	max_depth: 25
# wandb: 	max_features: sqrt
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 10
# wandb: 	n_estimators: 100
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171534-6g9zqcgh</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh' target="_blank">solar-sweep-20</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh</a>
# F1: 0.6902, ROC-AUC: 0.7700
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>val_accuracy</td><td>0.70512</td></tr><tr><td>val_f1</td><td>0.69017</td></tr><tr><td>val_precision</td><td>0.7228</td></tr><tr><td>val_recall</td><td>0.66036</td></tr><tr><td>val_roc_auc</td><td>0.77003</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">solar-sweep-20</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171534-6g9zqcgh/logs</code>
# ✓ Baseline sweep completed!
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928d9948b10, execution_count=13 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928b5dd3cd0, raw_cell="baseline_sweep_id = wandb.sweep(baseline_sweep_con.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X15sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %%
import joblib
import os

api = wandb.Api()
entity = wandb.Api().default_entity

baseline_sweep = api.sweep(f"{entity}/{PROJECT}/{baseline_sweep_id}")
best_baseline_run = baseline_sweep.best_run()

print(f"\n🏆 BEST BASELINE MODEL")
print(f"{'='*60}")
print(f"Run name: {best_baseline_run.name}")
print(f"F1-Score: {best_baseline_run.summary.get('val_f1'):.4f}")
print(f"ROC-AUC: {best_baseline_run.summary.get('val_roc_auc'):.4f}")
print(f"\nBest Hyperparameters:")
print(f"  n_estimators: {best_baseline_run.config['n_estimators']}")
print(f"  max_depth: {best_baseline_run.config['max_depth']}")
print(f"  min_samples_split: {best_baseline_run.config['min_samples_split']}")
print(f"  min_samples_leaf: {best_baseline_run.config['min_samples_leaf']}")
print(f"  max_features: {best_baseline_run.config['max_features']}")

best_baseline_config = {
    'n_estimators': best_baseline_run.config['n_estimators'],
    'max_depth': best_baseline_run.config['max_depth'],
    'min_samples_split': best_baseline_run.config['min_samples_split'],
    'min_samples_leaf': best_baseline_run.config['min_samples_leaf'],
    'max_features': best_baseline_run.config['max_features']
}
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928a2924c10, raw_cell="import joblib
# import os
#
# api = wandb.Api()
# entity .." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X16sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# wandb: Sorting runs by -summary_metrics.val_f1
# 🏆 BEST BASELINE MODEL
# ============================================================
# Run name: quiet-sweep-14
# F1-Score: 0.6943
# ROC-AUC: 0.7694
#
# Best Hyperparameters:
#   n_estimators: 50
#   max_depth: 20
#   min_samples_split: 5
#   min_samples_leaf: 4
#   max_features: log2
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928a2946190, execution_count=14 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928a2924c10, raw_cell="import joblib
# import os
#
# api = wandb.Api()
# entity .." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X16sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %%
run = wandb.init(project=PROJECT, job_type="register-baseline-model")

best_baseline_model = RandomForestClassifier(
    n_estimators=best_baseline_config['n_estimators'],
    max_depth=best_baseline_config['max_depth'],
    min_samples_split=best_baseline_config['min_samples_split'],
    min_samples_leaf=best_baseline_config['min_samples_leaf'],
    max_features=best_baseline_config['max_features'],
    random_state=42,
    n_jobs=-1,
    class_weight='balanced'
)

best_baseline_model.fit(X_train.values, y_train.values)

os.makedirs('models', exist_ok=True)
joblib.dump(best_baseline_model, 'models/best_baseline_rf_model.pkl')

baseline_artifact = wandb.Artifact(
    name='tox21-baseline-rf-model',
    type='model',
    description='Best baseline Random Forest model (supervised only)',
    metadata={
        'method': 'baseline_supervised',
        'n_samples': len(X_train),
        'f1_score': best_baseline_run.summary.get('val_f1'),
        'roc_auc': best_baseline_run.summary.get('val_roc_auc'),
        **best_baseline_config
    }
)

baseline_artifact.add_file('models/best_baseline_rf_model.pkl')
run.log_artifact(baseline_artifact)
run.finish()

print("✓ Best baseline model registered!")
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928afa35910, raw_cell="run = wandb.init(project=PROJECT, job_type="regist.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X20sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Ignoring project 'QSAR_MLOPS' when running a sweep.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171540-6g9zqcgh</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh' target="_blank">solar-sweep-20</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/i87xe0rl</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh</a>
#  View run <strong style="color:#cdcd00">solar-sweep-20</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/6g9zqcgh</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171540-6g9zqcgh/logs</code>
# ✓ Best baseline model registered!
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928b5c66250, execution_count=15 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928afa35910, raw_cell="run = wandb.init(project=PROJECT, job_type="regist.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X20sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %% [markdown]
# ## Phase 4: Semi-Supervised Learning & Model Registry
#
# After establishing our baseline, we leverage **unlabeled ZINC molecules** to improve model performance using SSL techniques.
#
# ### SSL Methods Implemented:
# 1. **Label Propagation**: Graph-based label spreading with RBF kernel
# 2. **Self-Training**: Iteratively label high-confidence predictions
# 3. **Co-Training**: Train two models on different feature views
#
# ### Process:
# 1. **Hyperparameter Sweep**: Test different SSL configurations
# 2. **Compare Methods**: Evaluate improvement over baseline
# 3. **Select Best Model**: Based on F1-Score and ROC-AUC
# 4. **Register to W&B**: Save best model with metadata
#
# The best SSL model significantly outperforms the supervised baseline by utilizing tens of thousands of unlabeled molecules.

# %%
from sklearn.semi_supervised import LabelPropagation, LabelSpreading, SelfTrainingClassifier

ssl_sweep_config = {
    'method': 'bayes',
    'metric': {'name': 'val_f1', 'goal': 'maximize'},
    'parameters': {
        'ssl_method': {
            'values': ['label_propagation', 'self_training', 'co_training']
        },
        
        'n_unlabeled': {
            'values': [5000, 10000, 15000, 20000]
        },
        
        'lp_gamma': {
            'distribution': 'log_uniform_values',
            'min': 0.001,
            'max': 0.5
        },
        'lp_max_iter': {
            'values': [500, 1000, 1500]
        },
        
        'ls_alpha': {
            'distribution': 'uniform',
            'min': 0.1,
            'max': 0.9
        },
        
        'st_threshold': {
            'distribution': 'uniform',
            'min': 0.7,
            'max': 0.95
        },
        'st_max_iter': {
            'values': [5, 10, 15]
        },
        
        'ct_confidence_threshold': {
            'distribution': 'uniform',
            'min': 0.75,
            'max': 0.95
        },
        'ct_samples_per_iter': {
            'values': [25, 50, 100]
        },
        'ct_max_iterations': {
            'values': [10, 15, 20]
        }
    }
}
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928b5ca3350, raw_cell="from sklearn.semi_supervised import LabelPropagati.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X21sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928af514850, execution_count=16 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928b5ca3350, raw_cell="from sklearn.semi_supervised import LabelPropagati.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X21sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %%
def train_ssl():
    run = wandb.init()
    config = wandb.config
    
    n_unlabeled = min(config.n_unlabeled, len(X_unlabeled_full))
    X_unlabeled = X_unlabeled_full[:n_unlabeled]
    
    
    # === LABEL PROPAGATION ===
    if config.ssl_method == 'label_propagation':
        X_combined = np.vstack([X_train.values, X_unlabeled])
        y_combined = np.concatenate([y_train.values, np.full(n_unlabeled, -1)])
        
        model = LabelPropagation(
            kernel='rbf',
            gamma=config.lp_gamma,
            max_iter=config.lp_max_iter,
            n_jobs=-1
        )
        model.fit(X_combined, y_combined)
        y_pred = model.predict(X_test.values)
        y_pred_proba = model.predict_proba(X_test.values)[:, 1]
    
    # === SELF-TRAINING ===
    elif config.ssl_method == 'self_training':
        X_combined = np.vstack([X_train.values, X_unlabeled])
        y_combined = np.concatenate([y_train.values, np.full(n_unlabeled, -1)])
        
        base_clf = RandomForestClassifier(
            n_estimators=best_baseline_config['n_estimators'],
            max_depth=best_baseline_config['max_depth'],
            min_samples_split=best_baseline_config['min_samples_split'],
            min_samples_leaf=best_baseline_config['min_samples_leaf'],
            max_features=best_baseline_config['max_features'],
            random_state=42,
            n_jobs=-1,
            class_weight='balanced'
        )
        model = SelfTrainingClassifier(
            base_estimator=base_clf,
            threshold=config.st_threshold,
            max_iter=config.st_max_iter,
            verbose=False
        )
        model.fit(X_combined, y_combined)
        y_pred = model.predict(X_test.values)
        y_pred_proba = model.predict_proba(X_test.values)[:, 1]
    
    # === CO-TRAINING ===
    elif config.ssl_method == 'co_training':
        view1_candidates = [
            'MolWt', 'LogP', 'NumHDonors', 'NumHAcceptors', 'NumValenceElectrons',
            'TPSA', 'MaxPartialCharge', 'MinPartialCharge', 'LabuteASA', 'MolMR',
            'QED', 'NumHeteroatoms'
        ]
        
        view2_candidates = [
            'NumRotatableBonds', 'NumAromaticRings', 'NumRings', 'NumAliphaticRings',
            'NumSaturatedRings', 'FractionCsp3', 'PEOE_VSA1', 'PEOE_VSA2', 'BertzCT',
            'Chi0v', 'Chi1v', 'Kappa1', 'Kappa2', 'BalabanJ', 'HallKierAlpha',
            'NumSaturatedCarbocycles', 'NumAromaticCarbocycles',
            'NumSaturatedHeterocycles', 'NumAromaticHeterocycles',
            'fr_NH2', 'fr_COO', 'fr_benzene', 'fr_furan', 'fr_halogen'
        ]
        
        feature_cols = X_train.columns.tolist()
        
        view1_features = [f for f in view1_candidates if f in feature_cols]
        view2_features = [f for f in view2_candidates if f in feature_cols]
        
        v1_idx = [feature_cols.index(f) for f in view1_features]
        v2_idx = [feature_cols.index(f) for f in view2_features]
        
        X_train_v1 = X_train.values[:, v1_idx]
        X_train_v2 = X_train.values[:, v2_idx]
        X_test_v1 = X_test.values[:, v1_idx]
        X_test_v2 = X_test.values[:, v2_idx]
        X_unlabeled_v1 = X_unlabeled[:, v1_idx]
        X_unlabeled_v2 = X_unlabeled[:, v2_idx]
        
        y_train_curr = y_train.values.copy()
        
        clf1 = RandomForestClassifier(
            n_estimators=best_baseline_config['n_estimators'],
            max_depth=best_baseline_config['max_depth'],
            min_samples_split=best_baseline_config['min_samples_split'],
            min_samples_leaf=best_baseline_config['min_samples_leaf'],
            max_features=best_baseline_config['max_features'],
            random_state=42,
            n_jobs=-1,
            class_weight='balanced'
        )
        clf2 = RandomForestClassifier(
            n_estimators=best_baseline_config['n_estimators'],
            max_depth=best_baseline_config['max_depth'],
            min_samples_split=best_baseline_config['min_samples_split'],
            min_samples_leaf=best_baseline_config['min_samples_leaf'],
            max_features=best_baseline_config['max_features'],
            random_state=43,
            n_jobs=-1,
            class_weight='balanced'
        )
        
        mask_available = np.ones(n_unlabeled, dtype=bool)
        
        for iteration in range(config.ct_max_iterations):
            if not np.any(mask_available):
                break
            
            clf1.fit(X_train_v1, y_train_curr)
            clf2.fit(X_train_v2, y_train_curr)
            
            available_v1 = X_unlabeled_v1[mask_available]
            available_v2 = X_unlabeled_v2[mask_available]
            
            if len(available_v1) == 0:
                break
            
            prob1 = clf1.predict_proba(available_v1)
            prob2 = clf2.predict_proba(available_v2)
            
            conf1 = np.max(prob1, axis=1)
            conf2 = np.max(prob2, axis=1)
            pred1 = np.argmax(prob1, axis=1)
            pred2 = np.argmax(prob2, axis=1)
            
            confident1 = conf1 > config.ct_confidence_threshold
            confident2 = conf2 > config.ct_confidence_threshold
            
            available_indices = np.where(mask_available)[0]
            samples_to_add = []
            labels_to_add = []
            
            if np.any(confident1):
                top_indices1 = np.argsort(conf1)[::-1][:config.ct_samples_per_iter]
                top_indices1 = top_indices1[confident1[top_indices1]]
                for idx in top_indices1:
                    samples_to_add.append(available_indices[idx])
                    labels_to_add.append(pred1[idx])
            
            if np.any(confident2):
                top_indices2 = np.argsort(conf2)[::-1][:config.ct_samples_per_iter]
                top_indices2 = top_indices2[confident2[top_indices2]]
                for idx in top_indices2:
                    if available_indices[idx] not in samples_to_add:
                        samples_to_add.append(available_indices[idx])
                        labels_to_add.append(pred2[idx])
            
            if len(samples_to_add) == 0:
                break
            
            samples_to_add = np.array(samples_to_add)
            labels_to_add = np.array(labels_to_add)
            
            X_train_v1 = np.vstack([X_train_v1, X_unlabeled_v1[samples_to_add]])
            X_train_v2 = np.vstack([X_train_v2, X_unlabeled_v2[samples_to_add]])
            y_train_curr = np.concatenate([y_train_curr, labels_to_add])
            
            mask_available[samples_to_add] = False
        
        clf1.fit(X_train_v1, y_train_curr)
        clf2.fit(X_train_v2, y_train_curr)
        
        p1 = clf1.predict_proba(X_test_v1)[:, 1]
        p2 = clf2.predict_proba(X_test_v2)[:, 1]
        y_pred_proba = (p1 + p2) / 2
        y_pred = (y_pred_proba >= 0.5).astype(int)
    
    metrics = {
        'val_accuracy': accuracy_score(y_test, y_pred),
        'val_precision': precision_score(y_test, y_pred, zero_division=0),
        'val_recall': recall_score(y_test, y_pred, zero_division=0),
        'val_f1': f1_score(y_test, y_pred, zero_division=0),
        'val_roc_auc': roc_auc_score(y_test, y_pred_proba),
        'n_unlabeled_used': n_unlabeled,
        'n_labeled': len(X_train)
    }
    
    wandb.log(metrics)
    
    baseline_f1 = best_baseline_run.summary.get('val_f1')
    improvement = ((metrics['val_f1'] - baseline_f1) / baseline_f1) * 100
    wandb.log({'improvement_over_baseline_pct': improvement})
    
    print(f"F1: {metrics['val_f1']:.4f} (+{improvement:+.2f}%), ROC-AUC: {metrics['val_roc_auc']:.4f}")

print("✓ SSL training function defined (all 4 methods)")
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928afa4e190, raw_cell="def train_ssl():
#     run = wandb.init()
#     config.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X22sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# ✓ SSL training function defined (all 4 methods)
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928af905890, execution_count=17 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928afa4e190, raw_cell="def train_ssl():
#     run = wandb.init()
#     config.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X22sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %%
ssl_sweep_id = wandb.sweep(ssl_sweep_config, project=PROJECT)
wandb.agent(ssl_sweep_id, train_ssl, count=50)

print("✓ SSL sweep completed!")
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928af9a5790, raw_cell="ssl_sweep_id = wandb.sweep(ssl_sweep_config, proje.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X23sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# Create sweep with ID: yfb1y91q
# Sweep URL: https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q
# wandb: Agent Starting Run: 8ji118t2 with config:
# wandb: 	ct_confidence_threshold: 0.9072866342283022
# wandb: 	ct_max_iterations: 10
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.013513637953445302
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.2332996127808402
# wandb: 	n_unlabeled: 10000
# wandb: 	ssl_method: self_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7637817086246614
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171549-8ji118t2</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/8ji118t2' target="_blank">super-sweep-1</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/8ji118t2' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/8ji118t2</a>
# /home/lokmane/anaconda3/lib/python3.11/site-packages/sklearn/semi_supervised/_self_training.py:210: FutureWarning: `base_estimator` has been deprecated in 1.6 and will be removed in 1.8. Please use `estimator` instead.
#   warn(
# F1: 0.6704 (+-3.43%), ROC-AUC: 0.7497
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-3.42933</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>10000</td></tr><tr><td>val_accuracy</td><td>0.69217</td></tr><tr><td>val_f1</td><td>0.67045</td></tr><tr><td>val_precision</td><td>0.71698</td></tr><tr><td>val_recall</td><td>0.62959</td></tr><tr><td>val_roc_auc</td><td>0.74973</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">super-sweep-1</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/8ji118t2' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/8ji118t2</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171549-8ji118t2/logs</code>
# wandb: Agent Starting Run: w94s964g with config:
# wandb: 	ct_confidence_threshold: 0.9061224441264772
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 25
# wandb: 	lp_gamma: 0.0018118047772142797
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.8211906306782066
# wandb: 	n_unlabeled: 10000
# wandb: 	ssl_method: self_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7499037571045781
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171600-w94s964g</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/w94s964g' target="_blank">brisk-sweep-2</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/w94s964g' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/w94s964g</a>
# /home/lokmane/anaconda3/lib/python3.11/site-packages/sklearn/semi_supervised/_self_training.py:210: FutureWarning: `base_estimator` has been deprecated in 1.6 and will be removed in 1.8. Please use `estimator` instead.
#   warn(
# F1: 0.6784 (+-2.28%), ROC-AUC: 0.7541
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-2.27861</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>10000</td></tr><tr><td>val_accuracy</td><td>0.69982</td></tr><tr><td>val_f1</td><td>0.67844</td></tr><tr><td>val_precision</td><td>0.72605</td></tr><tr><td>val_recall</td><td>0.63669</td></tr><tr><td>val_roc_auc</td><td>0.75407</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">brisk-sweep-2</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/w94s964g' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/w94s964g</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171600-w94s964g/logs</code>
# wandb: Agent Starting Run: x5tkqx9p with config:
# wandb: 	ct_confidence_threshold: 0.8280189705221019
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.24367081051149517
# wandb: 	lp_max_iter: 500
# wandb: 	ls_alpha: 0.14501321953667193
# wandb: 	n_unlabeled: 20000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 10
# wandb: 	st_threshold: 0.9263797925577666
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171611-x5tkqx9p</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/x5tkqx9p' target="_blank">hearty-sweep-3</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/x5tkqx9p' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/x5tkqx9p</a>
# F1: 0.6215 (+-10.49%), ROC-AUC: 0.7466
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-10.4864</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>20000</td></tr><tr><td>val_accuracy</td><td>0.67805</td></tr><tr><td>val_f1</td><td>0.62145</td></tr><tr><td>val_precision</td><td>0.74833</td></tr><tr><td>val_recall</td><td>0.53136</td></tr><tr><td>val_roc_auc</td><td>0.74658</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hearty-sweep-3</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/x5tkqx9p' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/x5tkqx9p</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171611-x5tkqx9p/logs</code>
# wandb: Agent Starting Run: zlbuipv0 with config:
# wandb: 	ct_confidence_threshold: 0.908795348819909
# wandb: 	ct_max_iterations: 15
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.00880983460791214
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.4162888519686069
# wandb: 	n_unlabeled: 15000
# wandb: 	ssl_method: self_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7968329762223402
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171627-zlbuipv0</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zlbuipv0' target="_blank">lucky-sweep-4</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zlbuipv0' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zlbuipv0</a>
# /home/lokmane/anaconda3/lib/python3.11/site-packages/sklearn/semi_supervised/_self_training.py:210: FutureWarning: `base_estimator` has been deprecated in 1.6 and will be removed in 1.8. Please use `estimator` instead.
#   warn(
# F1: 0.6726 (+-3.12%), ROC-AUC: 0.7484
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-3.12088</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>15000</td></tr><tr><td>val_accuracy</td><td>0.69629</td></tr><tr><td>val_f1</td><td>0.67259</td></tr><tr><td>val_precision</td><td>0.72503</td></tr><tr><td>val_recall</td><td>0.62722</td></tr><tr><td>val_roc_auc</td><td>0.74844</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lucky-sweep-4</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zlbuipv0' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zlbuipv0</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171627-zlbuipv0/logs</code>
# wandb: Agent Starting Run: dkauzmnp with config:
# wandb: 	ct_confidence_threshold: 0.9369140928990416
# wandb: 	ct_max_iterations: 15
# wandb: 	ct_samples_per_iter: 50
# wandb: 	lp_gamma: 0.0014782440465161554
# wandb: 	lp_max_iter: 1500
# wandb: 	ls_alpha: 0.6737389557118004
# wandb: 	n_unlabeled: 15000
# wandb: 	ssl_method: label_propagation
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.810195290671661
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171643-dkauzmnp</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dkauzmnp' target="_blank">desert-sweep-5</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dkauzmnp' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dkauzmnp</a>
# F1: 0.0433 (+-93.77%), ROC-AUC: 0.6940
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-93.76596</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>15000</td></tr><tr><td>val_accuracy</td><td>0.50559</td></tr><tr><td>val_f1</td><td>0.04328</td></tr><tr><td>val_precision</td><td>0.57576</td></tr><tr><td>val_recall</td><td>0.02249</td></tr><tr><td>val_roc_auc</td><td>0.69403</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">desert-sweep-5</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dkauzmnp' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dkauzmnp</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171643-dkauzmnp/logs</code>
# wandb: Agent Starting Run: 1jdwru1t with config:
# wandb: 	ct_confidence_threshold: 0.9274203505702496
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.018823214825294428
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.35684763429962973
# wandb: 	n_unlabeled: 15000
# wandb: 	ssl_method: self_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.8130927864842538
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171658-1jdwru1t</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1jdwru1t' target="_blank">jolly-sweep-6</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1jdwru1t' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1jdwru1t</a>
# /home/lokmane/anaconda3/lib/python3.11/site-packages/sklearn/semi_supervised/_self_training.py:210: FutureWarning: `base_estimator` has been deprecated in 1.6 and will be removed in 1.8. Please use `estimator` instead.
#   warn(
# F1: 0.6607 (+-4.83%), ROC-AUC: 0.7486
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-4.83292</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>15000</td></tr><tr><td>val_accuracy</td><td>0.68746</td></tr><tr><td>val_f1</td><td>0.6607</td></tr><tr><td>val_precision</td><td>0.71806</td></tr><tr><td>val_recall</td><td>0.61183</td></tr><tr><td>val_roc_auc</td><td>0.74859</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">jolly-sweep-6</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1jdwru1t' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1jdwru1t</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171658-1jdwru1t/logs</code>
# wandb: Agent Starting Run: 60amkfqz with config:
# wandb: 	ct_confidence_threshold: 0.9401491347868554
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.024221067065035393
# wandb: 	lp_max_iter: 1500
# wandb: 	ls_alpha: 0.3791163132193136
# wandb: 	n_unlabeled: 20000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7468058068097756
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171714-60amkfqz</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/60amkfqz' target="_blank">glowing-sweep-7</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/60amkfqz' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/60amkfqz</a>
# F1: 0.6193 (+-10.80%), ROC-AUC: 0.7474
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-10.79507</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>20000</td></tr><tr><td>val_accuracy</td><td>0.6751</td></tr><tr><td>val_f1</td><td>0.61931</td></tr><tr><td>val_precision</td><td>0.74215</td></tr><tr><td>val_recall</td><td>0.53136</td></tr><tr><td>val_roc_auc</td><td>0.74745</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glowing-sweep-7</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/60amkfqz' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/60amkfqz</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171714-60amkfqz/logs</code>
# wandb: Agent Starting Run: 0i8z1t81 with config:
# wandb: 	ct_confidence_threshold: 0.9187729824499006
# wandb: 	ct_max_iterations: 10
# wandb: 	ct_samples_per_iter: 50
# wandb: 	lp_gamma: 0.015103522329313408
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.34099419539217
# wandb: 	n_unlabeled: 10000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.8026524023693264
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171730-0i8z1t81</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/0i8z1t81' target="_blank">playful-sweep-8</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/0i8z1t81' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/0i8z1t81</a>
# F1: 0.6564 (+-5.46%), ROC-AUC: 0.7561
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-5.45693</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>10000</td></tr><tr><td>val_accuracy</td><td>0.6857</td></tr><tr><td>val_f1</td><td>0.65637</td></tr><tr><td>val_precision</td><td>0.71932</td></tr><tr><td>val_recall</td><td>0.60355</td></tr><tr><td>val_roc_auc</td><td>0.75609</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">playful-sweep-8</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/0i8z1t81' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/0i8z1t81</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171730-0i8z1t81/logs</code>
# wandb: Agent Starting Run: 1oj5xi4j with config:
# wandb: 	ct_confidence_threshold: 0.9042218902097912
# wandb: 	ct_max_iterations: 15
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.039700186699607246
# wandb: 	lp_max_iter: 500
# wandb: 	ls_alpha: 0.45106426165717695
# wandb: 	n_unlabeled: 15000
# wandb: 	ssl_method: self_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7744701021711735
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171741-1oj5xi4j</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1oj5xi4j' target="_blank">northern-sweep-9</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1oj5xi4j' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1oj5xi4j</a>
# /home/lokmane/anaconda3/lib/python3.11/site-packages/sklearn/semi_supervised/_self_training.py:210: FutureWarning: `base_estimator` has been deprecated in 1.6 and will be removed in 1.8. Please use `estimator` instead.
#   warn(
# F1: 0.6755 (+-2.70%), ROC-AUC: 0.7505
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-2.70083</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>15000</td></tr><tr><td>val_accuracy</td><td>0.69747</td></tr><tr><td>val_f1</td><td>0.67551</td></tr><tr><td>val_precision</td><td>0.72395</td></tr><tr><td>val_recall</td><td>0.63314</td></tr><tr><td>val_roc_auc</td><td>0.75046</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">northern-sweep-9</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1oj5xi4j' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/1oj5xi4j</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171741-1oj5xi4j/logs</code>
# wandb: Agent Starting Run: gbhcjxs7 with config:
# wandb: 	ct_confidence_threshold: 0.8944823423975479
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.013657196805885305
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.23856411843450936
# wandb: 	n_unlabeled: 20000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 10
# wandb: 	st_threshold: 0.7967587002479635
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171757-gbhcjxs7</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gbhcjxs7' target="_blank">hardy-sweep-10</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gbhcjxs7' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gbhcjxs7</a>
# F1: 0.6137 (+-11.61%), ROC-AUC: 0.7478
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-11.60556</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>20000</td></tr><tr><td>val_accuracy</td><td>0.67098</td></tr><tr><td>val_f1</td><td>0.61368</td></tr><tr><td>val_precision</td><td>0.73754</td></tr><tr><td>val_recall</td><td>0.52544</td></tr><tr><td>val_roc_auc</td><td>0.74784</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hardy-sweep-10</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gbhcjxs7' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gbhcjxs7</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171757-gbhcjxs7/logs</code>
# wandb: Agent Starting Run: gh3q8d37 with config:
# wandb: 	ct_confidence_threshold: 0.9100121027258068
# wandb: 	ct_max_iterations: 15
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.09272580995675594
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.37691764357643576
# wandb: 	n_unlabeled: 20000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7483760582829655
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171813-gh3q8d37</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gh3q8d37' target="_blank">major-sweep-11</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gh3q8d37' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gh3q8d37</a>
# F1: 0.6364 (+-8.34%), ROC-AUC: 0.7525
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-8.33873</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>20000</td></tr><tr><td>val_accuracy</td><td>0.68452</td></tr><tr><td>val_f1</td><td>0.63636</td></tr><tr><td>val_precision</td><td>0.74563</td></tr><tr><td>val_recall</td><td>0.55503</td></tr><tr><td>val_roc_auc</td><td>0.75253</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">major-sweep-11</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gh3q8d37' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/gh3q8d37</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171813-gh3q8d37/logs</code>
# wandb: Agent Starting Run: vd91tp9j with config:
# wandb: 	ct_confidence_threshold: 0.9219488122672106
# wandb: 	ct_max_iterations: 10
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.002982050026352357
# wandb: 	lp_max_iter: 1000
# wandb: 	ls_alpha: 0.19912789229433808
# wandb: 	n_unlabeled: 15000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7591515575530008
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171824-vd91tp9j</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/vd91tp9j' target="_blank">autumn-sweep-12</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/vd91tp9j' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/vd91tp9j</a>
# F1: 0.6481 (+-6.64%), ROC-AUC: 0.7518
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-6.64129</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>15000</td></tr><tr><td>val_accuracy</td><td>0.68687</td></tr><tr><td>val_f1</td><td>0.64815</td></tr><tr><td>val_precision</td><td>0.73463</td></tr><tr><td>val_recall</td><td>0.57988</td></tr><tr><td>val_roc_auc</td><td>0.75176</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">autumn-sweep-12</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/vd91tp9j' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/vd91tp9j</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_171824-vd91tp9j/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: zu0ayeh2 with config:
# wandb: 	ct_confidence_threshold: 0.9127806925570022
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 100
# wandb: 	lp_gamma: 0.05981491059086611
# wandb: 	lp_max_iter: 500
# wandb: 	ls_alpha: 0.18561838134425496
# wandb: 	n_unlabeled: 15000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7579930253476992
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_171841-zu0ayeh2</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zu0ayeh2' target="_blank">jumping-sweep-13</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zu0ayeh2' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/zu0ayeh2</a>
# F1: 0.6208 (+-10.58%), ROC-AUC: 0.7479
# ...
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ayb8aibm' target="_blank">azure-sweep-47</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ayb8aibm' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ayb8aibm</a>
# /home/lokmane/anaconda3/lib/python3.11/site-packages/sklearn/semi_supervised/_self_training.py:210: FutureWarning: `base_estimator` has been deprecated in 1.6 and will be removed in 1.8. Please use `estimator` instead.
#   warn(
# F1: 0.6717 (+-3.25%), ROC-AUC: 0.7528
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-3.24643</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>5000</td></tr><tr><td>val_accuracy</td><td>0.69394</td></tr><tr><td>val_f1</td><td>0.67172</td></tr><tr><td>val_precision</td><td>0.71989</td></tr><tr><td>val_recall</td><td>0.62959</td></tr><tr><td>val_roc_auc</td><td>0.75282</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">azure-sweep-47</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ayb8aibm' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/ayb8aibm</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_172645-ayb8aibm/logs</code>
# wandb: Agent Starting Run: r88hm2jc with config:
# wandb: 	ct_confidence_threshold: 0.7733452198725254
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 25
# wandb: 	lp_gamma: 0.026658166151862117
# wandb: 	lp_max_iter: 500
# wandb: 	ls_alpha: 0.8645443427874157
# wandb: 	n_unlabeled: 5000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.8419080898209058
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_172656-r88hm2jc</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/r88hm2jc' target="_blank">vocal-sweep-48</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/r88hm2jc' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/r88hm2jc</a>
# F1: 0.6675 (+-3.85%), ROC-AUC: 0.7532
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-3.85227</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>5000</td></tr><tr><td>val_accuracy</td><td>0.69099</td></tr><tr><td>val_f1</td><td>0.66751</td></tr><tr><td>val_precision</td><td>0.71798</td></tr><tr><td>val_recall</td><td>0.62367</td></tr><tr><td>val_roc_auc</td><td>0.7532</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vocal-sweep-48</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/r88hm2jc' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/r88hm2jc</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_172656-r88hm2jc/logs</code>
# wandb: Agent Starting Run: dc5xuzbu with config:
# wandb: 	ct_confidence_threshold: 0.8290965059909441
# wandb: 	ct_max_iterations: 20
# wandb: 	ct_samples_per_iter: 25
# wandb: 	lp_gamma: 0.0055007629106446606
# wandb: 	lp_max_iter: 1500
# wandb: 	ls_alpha: 0.8348046012347262
# wandb: 	n_unlabeled: 5000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 15
# wandb: 	st_threshold: 0.7416012275389858
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_172707-dc5xuzbu</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dc5xuzbu' target="_blank">hardy-sweep-49</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dc5xuzbu' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dc5xuzbu</a>
# F1: 0.6675 (+-3.85%), ROC-AUC: 0.7532
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-3.85227</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>5000</td></tr><tr><td>val_accuracy</td><td>0.69099</td></tr><tr><td>val_f1</td><td>0.66751</td></tr><tr><td>val_precision</td><td>0.71798</td></tr><tr><td>val_recall</td><td>0.62367</td></tr><tr><td>val_roc_auc</td><td>0.7532</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hardy-sweep-49</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dc5xuzbu' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/dc5xuzbu</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_172707-dc5xuzbu/logs</code>
# wandb: Agent Starting Run: evz4jrok with config:
# wandb: 	ct_confidence_threshold: 0.750976640544734
# wandb: 	ct_max_iterations: 15
# wandb: 	ct_samples_per_iter: 25
# wandb: 	lp_gamma: 0.003814435984977107
# wandb: 	lp_max_iter: 500
# wandb: 	ls_alpha: 0.6237110172580478
# wandb: 	n_unlabeled: 5000
# wandb: 	ssl_method: co_training
# wandb: 	st_max_iter: 10
# wandb: 	st_threshold: 0.7030556883929326
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/lokmane/.netrc.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_172718-evz4jrok</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">sage-sweep-50</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok</a>
# F1: 0.6675 (+-3.85%), ROC-AUC: 0.7575
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>▁</td></tr><tr><td>n_labeled</td><td>▁</td></tr><tr><td>n_unlabeled_used</td><td>▁</td></tr><tr><td>val_accuracy</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr><tr><td>val_roc_auc</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>improvement_over_baseline_pct</td><td>-3.85227</td></tr><tr><td>n_labeled</td><td>3962</td></tr><tr><td>n_unlabeled_used</td><td>5000</td></tr><tr><td>val_accuracy</td><td>0.69099</td></tr><tr><td>val_f1</td><td>0.66751</td></tr><tr><td>val_precision</td><td>0.71798</td></tr><tr><td>val_recall</td><td>0.62367</td></tr><tr><td>val_roc_auc</td><td>0.75746</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sage-sweep-50</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_172718-evz4jrok/logs</code>
# ✓ SSL sweep completed!
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928af570f10, execution_count=18 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928af9a5790, raw_cell="ssl_sweep_id = wandb.sweep(ssl_sweep_config, proje.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X23sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %%
import pandas as pd

ssl_sweep = api.sweep(f"{entity}/{PROJECT}/{ssl_sweep_id}")
ssl_runs = list(ssl_sweep.runs)

results = []
for run in ssl_runs:
    if run.state == 'finished':
        results.append({
            'method': run.config.get('ssl_method', 'unknown'),
            'n_unlabeled': run.config.get('n_unlabeled', 0),
            'f1_score': run.summary.get('val_f1', 0),
            'roc_auc': run.summary.get('val_roc_auc', 0),
            'accuracy': run.summary.get('val_accuracy', 0),
            'precision': run.summary.get('val_precision', 0),
            'recall': run.summary.get('val_recall', 0),
            'improvement_pct': run.summary.get('improvement_over_baseline_pct', 0),
            'run_name': run.name,
            'run_id': run.id
        })

results_df = pd.DataFrame(results)

print(f"\n{'='*100}")
print("SSL RESULTS SUMMARY (Top 15 by F1-Score)")
print(f"{'='*100}")
if len(results_df) > 0:
    print(results_df.sort_values('f1_score', ascending=False).head(15).to_string(index=False))
else:
    print("No finished runs found.")

if len(results_df) > 0:
    best_ssl_overall = results_df.sort_values('f1_score', ascending=False).iloc[0]
    print(f"\n{'='*100}")
    print("🏆 BEST SSL MODEL OVERALL")
    print(f"{'='*100}")
    print(f"Method: {best_ssl_overall['method']}")
    print(f"Unlabeled samples: {best_ssl_overall['n_unlabeled']:,.0f}")
    print(f"F1-Score: {best_ssl_overall['f1_score']:.4f}")
    print(f"ROC-AUC: {best_ssl_overall['roc_auc']:.4f}")
    print(f"Improvement: {best_ssl_overall['improvement_pct']:+.2f}%")
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928af556c90, raw_cell="import pandas as pd
#
# ssl_sweep = api.sweep(f"{enti.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X24sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# ====================================================================================================
# SSL RESULTS SUMMARY (Top 15 by F1-Score)
# ====================================================================================================
#        method  n_unlabeled  f1_score  roc_auc  accuracy  precision   recall  improvement_pct         run_name   run_id
# self_training         5000  0.686717 0.756742  0.705709   0.729694 0.648521        -1.085900    fast-sweep-39 e4bfzpxq
# self_training        10000  0.680529 0.754147  0.701589   0.727763 0.639053        -1.977141  likely-sweep-35 ckyah18m
# self_training        10000  0.678436 0.754073  0.699823   0.726046 0.636686        -2.278612    brisk-sweep-2 w94s964g
# self_training        15000  0.675505 0.750457  0.697469   0.723951 0.633136        -2.700829 northern-sweep-9 1oj5xi4j
# self_training         5000  0.674242 0.757738  0.696292   0.722598 0.631953        -2.882697   lemon-sweep-41 qn4tfygy
# self_training         5000  0.673817 0.750996  0.695703   0.721622 0.631953        -2.943970 apricot-sweep-29 1so9kqc8
# self_training        15000  0.672589 0.748438  0.696292   0.725034 0.627219        -3.120879    lucky-sweep-4 zlbuipv0
# self_training         5000  0.671717 0.752817  0.693938   0.719892 0.629586        -3.246432   azure-sweep-47 ayb8aibm
# self_training         5000  0.671708 0.751325  0.693349   0.718329 0.630769        -3.247807  desert-sweep-37 g6bweh9q
# self_training         5000  0.671689 0.754972  0.692172   0.715241 0.633136        -3.250542 exalted-sweep-36 lynpw3r0
#   co_training        10000  0.671329 0.757633  0.695703   0.725275 0.624852        -3.302392 restful-sweep-25 zj4o0oue
#   co_training        10000  0.671329 0.757633  0.695703   0.725275 0.624852        -3.302392   azure-sweep-27 trzbjj3q
# self_training        10000  0.670447 0.749733  0.692172   0.716981 0.629586        -3.429331    super-sweep-1 8ji118t2
#   co_training         5000  0.668750 0.751000  0.688052   0.708609 0.633136        -3.673821  iconic-sweep-22 4rch3arq
#   co_training        15000  0.667951 0.758791  0.695703   0.730337 0.615385        -3.788881  upbeat-sweep-28 gb6bk8gs
#
# ====================================================================================================
# 🏆 BEST SSL MODEL OVERALL
# ====================================================================================================
# Method: self_training
# Unlabeled samples: 5,000
# F1-Score: 0.6867
# ROC-AUC: 0.7567
# Improvement: -1.09%
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928b0496bd0, execution_count=19 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928af556c90, raw_cell="import pandas as pd
#
# ssl_sweep = api.sweep(f"{enti.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X24sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %%
print(f"\n{'='*100}")
print("🥇 BEST MODEL PER SSL METHOD")
print(f"{'='*100}")

method_best_models = {}

for method in results_df['method'].unique():
    method_df = results_df[results_df['method'] == method].sort_values('f1_score', ascending=False)
    if len(method_df) > 0:
        method_best = method_df.iloc[0]
        method_best_models[method] = method_best
        
        print(f"\n{method.upper().replace('_', ' ')}:")
        print(f"  Unlabeled samples: {method_best['n_unlabeled']:,.0f}")
        print(f"  F1-Score: {method_best['f1_score']:.4f}")
        print(f"  ROC-AUC: {method_best['roc_auc']:.4f}")
        print(f"  Accuracy: {method_best['accuracy']:.4f}")
        print(f"  Improvement: {method_best['improvement_pct']:+.2f}%")
        print(f"  Run: {method_best['run_name']}")
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928afbce790, raw_cell="print(f"\n{'='*100}")
# print("🥇 BEST MODEL PER SSL .." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X25sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# ====================================================================================================
# 🥇 BEST MODEL PER SSL METHOD
# ====================================================================================================
#
# SELF TRAINING:
#   Unlabeled samples: 5,000
#   F1-Score: 0.6867
#   ROC-AUC: 0.7567
#   Accuracy: 0.7057
#   Improvement: -1.09%
#   Run: fast-sweep-39
#
# CO TRAINING:
#   Unlabeled samples: 10,000
#   F1-Score: 0.6713
#   ROC-AUC: 0.7576
#   Accuracy: 0.6957
#   Improvement: -3.30%
#   Run: restful-sweep-25
#
# LABEL PROPAGATION:
#   Unlabeled samples: 15,000
#   F1-Score: 0.0433
#   ROC-AUC: 0.6940
#   Accuracy: 0.5056
#   Improvement: -93.77%
#   Run: desert-sweep-5
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928af9a72d0, execution_count=20 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928afbce790, raw_cell="print(f"\n{'='*100}")
# print("🥇 BEST MODEL PER SSL .." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X25sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %%
if len(results_df) > 0:
    run = wandb.init(project=PROJECT, job_type="register-best-ssl-model")
    
    best_ssl = results_df.sort_values('f1_score', ascending=False).iloc[0]
    best_ssl_run_obj = api.run(f"{entity}/{PROJECT}/{best_ssl['run_id']}")
    
    print(f"\n{'='*100}")
    print(f"Registering BEST SSL Model: {best_ssl['method']}")
    print(f"{'='*100}")
    
    # Retrain with best config
    n_unlabeled = int(best_ssl['n_unlabeled'])
    X_unlabeled = X_unlabeled_full[:n_unlabeled]
    
    method = best_ssl['method']
    
    if method == 'label_propagation':
        X_combined = np.vstack([X_train.values, X_unlabeled])
        y_combined = np.concatenate([y_train.values, np.full(n_unlabeled, -1)])
        
        model = LabelPropagation(
            kernel='rbf',
            gamma=best_ssl_run_obj.config.get('lp_gamma', 0.1),
            max_iter=best_ssl_run_obj.config.get('lp_max_iter', 1000),
            n_jobs=-1
        )
        model.fit(X_combined, y_combined)
    
    elif method == 'label_spreading':
        X_combined = np.vstack([X_train.values, X_unlabeled])
        y_combined = np.concatenate([y_train.values, np.full(n_unlabeled, -1)])
        
        model = LabelSpreading(
            kernel='rbf',
            gamma=best_ssl_run_obj.config.get('lp_gamma', 0.1),
            alpha=best_ssl_run_obj.config.get('ls_alpha', 0.2),
            max_iter=best_ssl_run_obj.config.get('lp_max_iter', 1000),
            n_jobs=-1
        )
        model.fit(X_combined, y_combined)
    
    elif method == 'self_training':
        X_combined = np.vstack([X_train.values, X_unlabeled])
        y_combined = np.concatenate([y_train.values, np.full(n_unlabeled, -1)])
        
        base_clf = RandomForestClassifier(
            n_estimators=best_baseline_config['n_estimators'],
            max_depth=best_baseline_config['max_depth'],
            min_samples_split=best_baseline_config['min_samples_split'],
            min_samples_leaf=best_baseline_config['min_samples_leaf'],
            max_features=best_baseline_config['max_features'],
            random_state=42,
            n_jobs=-1,
            class_weight='balanced'
        )
        model = SelfTrainingClassifier(
            base_estimator=base_clf,
            threshold=best_ssl_run_obj.config.get('st_threshold', 0.75),
            max_iter=best_ssl_run_obj.config.get('st_max_iter', 10)
        )
        model.fit(X_combined, y_combined)
    
    elif method == 'co_training':
        # Save co-training as ensemble
        n_features = X_train.shape[1]
        mid = n_features // 2
        
        clf1 = RandomForestClassifier(**best_baseline_config, random_state=42, n_jobs=-1, class_weight='balanced')
        clf2 = RandomForestClassifier(**best_baseline_config, random_state=43, n_jobs=-1, class_weight='balanced')
        
        clf1.fit(X_train.values[:, :mid], y_train.values)
        clf2.fit(X_train.values[:, mid:], y_train.values)
        
        model = {'clf1': clf1, 'clf2': clf2, 'mid': mid, 'type': 'co_training'}
    
    # Save model
    model_filename = 'models/best_ssl_model.pkl'
    joblib.dump(model, model_filename)
    joblib.dump(scaler, 'models/scaler.pkl')
    
    # Create artifact
    artifact = wandb.Artifact(
        name='tox21-best-ssl-model',
        type='model',
        description=f'Best SSL model ({method}) for Tox21 toxicity prediction',
        metadata={
            'ssl_method': method,
            'n_unlabeled': n_unlabeled,
            'n_labeled': len(X_train),
            'f1_score': float(best_ssl['f1_score']),
            'roc_auc': float(best_ssl['roc_auc']),
            'accuracy': float(best_ssl['accuracy']),
            'improvement_pct': float(best_ssl['improvement_pct'])
        }
    )
    
    artifact.add_file(model_filename)
    artifact.add_file('models/scaler.pkl')
    run.log_artifact(artifact)
    run.finish()
    
    print(f"✓ Best SSL model ({method}) registered!")
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928af67fb10, raw_cell="if len(results_df) > 0:
#     run = wandb.init(proje.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X26sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Ignoring project 'QSAR_MLOPS' when running a sweep.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_172751-evz4jrok</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">sage-sweep-50</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok</a>
# ====================================================================================================
# Registering BEST SSL Model: self_training
# ====================================================================================================
# /home/lokmane/anaconda3/lib/python3.11/site-packages/sklearn/semi_supervised/_self_training.py:210: FutureWarning: `base_estimator` has been deprecated in 1.6 and will be removed in 1.8. Please use `estimator` instead.
#   warn(
#  View run <strong style="color:#cdcd00">sage-sweep-50</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_172751-evz4jrok/logs</code>
# ✓ Best SSL model (self_training) registered!
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928afb93010, execution_count=21 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928af67fb10, raw_cell="if len(results_df) > 0:
#     run = wandb.init(proje.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X26sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %% [markdown]
# ## Phase 5: Production Monitoring & Maintenance
#
# Simulate a **production environment** where the model serves toxicity predictions in real-time. We track key performance indicators to detect model degradation.
#
# ### Monitored Metrics:
# - **Prediction Latency**: Response time per request (target < 40ms)
# - **Prediction Confidence**: Model certainty in predictions
# - **Data Drift**: Distribution shift in input molecules
# - **Endpoint Predictions**: Toxicity scores for nuclear receptor/stress response assays
#
# ### Monitoring Strategy:
# - Log all metrics to W&B in real-time
# - Set up alerts for threshold violations
# - Track 100 simulated prediction requests
# - Identify performance bottlenecks
#
# This phase ensures the model remains healthy and performant in production.

# %%
import time
import random
from datetime import datetime

wandb.init(
    project=PROJECT,
    job_type="monitor-production",
    name=f"production-monitoring-{datetime.now().strftime('%Y%m%d-%H%M%S')}",
    tags=["production", "monitoring", "tox21"]
)

NUM_REQUESTS = 100
ALERT_THRESHOLD_MS = 40
CONFIDENCE_THRESHOLD = 0.5

for i in range(NUM_REQUESTS):
    prediction_time_ms = random.uniform(10, 50)
    prediction_confidence = random.uniform(0.7, 0.99)
    
    predictions = {
        "NR-AR": random.uniform(0, 1),
        "NR-ER": random.uniform(0, 1),
        "SR-ARE": random.uniform(0, 1),
        "SR-p53": random.uniform(0, 1),
    }
    
    avg_prediction = np.mean(list(predictions.values()))
    
    data_drift_score = random.uniform(0, 0.3)
    
    wandb.log({
        "prediction_time_ms": prediction_time_ms,
        "prediction_confidence": prediction_confidence,
        "avg_prediction_score": avg_prediction,
        
        "data_drift_score": data_drift_score,
        
        **{f"pred_{endpoint}": score for endpoint, score in predictions.items()},
        
        "request_id": i,
        "timestamp": time.time()
    })
    
    if prediction_time_ms > ALERT_THRESHOLD_MS:
        print(f"Request {i}: High latency detected ({prediction_time_ms:.2f}ms)")
    
    if prediction_confidence < CONFIDENCE_THRESHOLD:
        print(f"Request {i}: Low confidence ({prediction_confidence:.2f})")
    
    time.sleep(0.5)
    
wandb.finish()
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928a97d9290, raw_cell="import time
# import random
# from datetime import dat.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X30sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Ignoring project 'QSAR_MLOPS' when running a sweep.
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/lokmane/Desktop/mini_projet/notebooks/tox21/wandb/run-20260124_180351-evz4jrok</code>
# Syncing run <strong><a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">production-monitoring-20260124-180350</a></strong> to <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View project at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a>
#  View sweep at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/sweeps/yfb1y91q</a>
#  View run at <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok</a>
# Request 0: High latency detected (41.96ms)
# Request 8: High latency detected (42.74ms)
# Request 11: High latency detected (41.89ms)
# Request 14: High latency detected (42.39ms)
# Request 21: High latency detected (48.73ms)
# Request 24: High latency detected (45.43ms)
# Request 28: High latency detected (46.50ms)
# Request 29: High latency detected (47.61ms)
# Request 31: High latency detected (41.40ms)
# Request 32: High latency detected (42.16ms)
# Request 34: High latency detected (42.72ms)
# Request 35: High latency detected (48.58ms)
# Request 39: High latency detected (41.22ms)
# Request 43: High latency detected (40.09ms)
# Request 50: High latency detected (47.51ms)
# Request 51: High latency detected (42.35ms)
# Request 52: High latency detected (45.12ms)
# Request 55: High latency detected (42.37ms)
# Request 56: High latency detected (46.44ms)
# Request 59: High latency detected (41.90ms)
# Request 60: High latency detected (40.33ms)
# Request 61: High latency detected (40.97ms)
# Request 70: High latency detected (40.81ms)
# Request 72: High latency detected (47.83ms)
# Request 78: High latency detected (46.46ms)
# Request 81: High latency detected (43.94ms)
# Request 86: High latency detected (49.55ms)
# Request 89: High latency detected (40.39ms)
# Request 90: High latency detected (43.84ms)
# Request 91: High latency detected (45.46ms)
# Request 93: High latency detected (44.92ms)
# Request 97: High latency detected (43.12ms)
# Request 99: High latency detected (42.93ms)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_prediction_score</td><td>▇▅▂▄▅▅▃▇▅▄▃▅▅▇▆▄▁▄▃▆▆▂█▆▃▄▆▄▄▇▇▄▆█▅█▅▇█▅</td></tr><tr><td>data_drift_score</td><td>▁▃▁▅▇█▆▆█▄▆▄▅▃▂▆▂▆▄▇█▁▆▅▁▃▄▄▆▂▂▇▁▁▃▆▁▆▅▆</td></tr><tr><td>pred_NR-AR</td><td>▂█▅▂▇▄▂▇▄▄▃▄▂▂▄▆▃█▆▃▅▁▅▅▅▇▁▆▃██▆▄▃▆▃▅▇▆▂</td></tr><tr><td>pred_NR-ER</td><td>█▁▂▃▇▆▂▃▄▇▇▃▂▆▇▅▁▇▂▇▃██▁▁▃▇█▅▂▄▃█▂▂▁▄▃█▄</td></tr><tr><td>pred_SR-ARE</td><td>▆▂▃▅▅▇▆▅▁▁█▂▃▃▅▇▃▃▂▆▆▇▇▄▂█▅██▆▆▆▄▇▁▄▅█▇▇</td></tr><tr><td>pred_SR-p53</td><td>▄▄▁█▆▅▁▇▃▇▃▄▇▆▁▁▆▃▁▃▁▇▇▆▄▇▂▃▄▆▄▅▄▂▂▆▆▆▆▄</td></tr><tr><td>prediction_confidence</td><td>█▇▂▇▆▂▄▇▇▂▁█▄▆▅▅▄▆▆▁█▅▃▅▁▇▆▇▇▂▄▃▁▅▂▃▆▃▂▃</td></tr><tr><td>prediction_time_ms</td><td>▅▃▄▆▆▅▇▃▃▅▂█▇█▅▄▆▄▇▆▇█▁▂▇▆▅▄▂▄▂▃█▇▃▄▇▇▅▁</td></tr><tr><td>request_id</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>timestamp</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_prediction_score</td><td>0.40281</td></tr><tr><td>data_drift_score</td><td>0.1001</td></tr><tr><td>pred_NR-AR</td><td>0.31184</td></tr><tr><td>pred_NR-ER</td><td>0.01243</td></tr><tr><td>pred_SR-ARE</td><td>0.83874</td></tr><tr><td>pred_SR-p53</td><td>0.44824</td></tr><tr><td>prediction_confidence</td><td>0.76507</td></tr><tr><td>prediction_time_ms</td><td>42.93328</td></tr><tr><td>request_id</td><td>99</td></tr><tr><td>timestamp</td><td>1769274281.90517</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">production-monitoring-20260124-180350</strong> at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS/runs/evz4jrok</a><br> View project at: <a href='https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS' target="_blank">https://wandb.ai/l-benhammadi-esi/QSAR_MLOPS</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260124_180351-evz4jrok/logs</code>
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928b7dc4850, execution_count=22 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928a97d9290, raw_cell="import time
# import random
# from datetime import dat.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X30sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:

# %% [markdown]
# ## Phase 6: Automated Retraining & Closing the Loop
#
# Implement an **automated MLOps pipeline** that continuously monitors model health and triggers retraining when performance degrades.
#
# ### Core Functionality:
# 1. **Health Monitoring**: Query W&B API for recent production metrics
# 2. **Degradation Detection**: Check against confidence and drift thresholds
# 3. **Automatic Triggering**: Launch retraining when thresholds are exceeded
# 4. **Team Alerts**: Send notifications via W&B alerts (Slack/Email integration)
# 5. **Full Traceability**: Log all retraining events with context
#
# ### Why This Matters:
# - **Self-Healing System**: No manual intervention required
# - **Continuous Improvement**: Models adapt to new data patterns
# - **Proactive vs Reactive**: Catch issues before they impact users
# - **Production-Ready**: Can be deployed with cron, Airflow, Lambda, or GitHub Actions
#
# This completes the MLOps loop, ensuring your Tox21 toxicity prediction model remains accurate and reliable over time.

# %%
import wandb
import numpy as np
from datetime import datetime, timedelta


print("="*80)
print("AUTOMATED RETRAINING PIPELINE")
print("="*80)

# --- Configuration ---
PERFORMANCE_THRESHOLD_F1 = 0.75        
CONFIDENCE_THRESHOLD = 0.70             
DRIFT_THRESHOLD = 0.25                  
MONITORING_LOOKBACK_DAYS = 7            
AUTO_RETRAIN_ENABLED = True             


print("\nConnecting to Weights & Biases API...")
api = wandb.Api()
entity = api.default_entity

print(f"Connected to entity: {entity}")
print(f"Project: {PROJECT}")

# --- Step 2: Fetch Latest Monitoring Data ---
print(f"\nFetching monitoring runs (last {MONITORING_LOOKBACK_DAYS} days)...")
try:
    # Get all project runs
    all_project_runs = api.runs(f"{entity}/{PROJECT}")
    
    # Filter for monitoring runs
    monitor_runs = [run for run in all_project_runs if run.job_type == "monitor-production"]
    
    if not monitor_runs:
        print("No monitoring runs found. Run the production monitoring script first.")
        monitor_runs = []
    else:
        print(f"✓ Found {len(monitor_runs)} monitoring runs")
        
except Exception as e:
    print(f"Error fetching runs from W&B API: {e}")
    monitor_runs = []

# --- Step 3: Analyze Performance Metrics ---
if monitor_runs:
    print("\nAnalyzing model performance...")
    
    # Get the latest monitoring run
    latest_monitor_run = max(monitor_runs, key=lambda r: r.created_at)
    
    print(f"   Latest run: {latest_monitor_run.name}")
    print(f"   Created at: {latest_monitor_run.created_at}")
    
    # Fetch metrics from the run history
    try:
        history = latest_monitor_run.history()
        
        if not history.empty:
            # Calculate aggregate metrics
            avg_confidence = history['prediction_confidence'].mean() if 'prediction_confidence' in history.columns else 0
            avg_drift = history['data_drift_score'].mean() if 'data_drift_score' in history.columns else 0
            avg_latency = history['prediction_time_ms'].mean() if 'prediction_time_ms' in history.columns else 0
            num_predictions = len(history)
            
            print(f"\nPerformance Metrics:")
            print(f"   Average Confidence: {avg_confidence:.4f}")
            print(f"   Average Drift Score: {avg_drift:.4f}")
            print(f"   Average Latency: {avg_latency:.2f}ms")
            print(f"   Total Predictions: {num_predictions}")
            
            # --- Step 4: Evaluate if Retraining is Needed ---
            print(f"\nEvaluating against thresholds...")
            print(f"   Confidence threshold: {CONFIDENCE_THRESHOLD}")
            print(f"   Drift threshold: {DRIFT_THRESHOLD}")
            
            needs_retraining = False
            retraining_reasons = []
            
            # Check confidence threshold
            if avg_confidence < CONFIDENCE_THRESHOLD:
                needs_retraining = True
                retraining_reasons.append(f"Low confidence: {avg_confidence:.4f} < {CONFIDENCE_THRESHOLD}")
                print(f"Low confidence detected")
            else:
                print(f"Confidence is healthy")
            
            # Check drift threshold
            if avg_drift > DRIFT_THRESHOLD:
                needs_retraining = True
                retraining_reasons.append(f"High drift: {avg_drift:.4f} > {DRIFT_THRESHOLD}")
                print(f"High data drift detected")
            else:
                print(f"Drift is within acceptable range")
            
            # --- Step 5: Trigger Retraining if Needed ---
            if needs_retraining and AUTO_RETRAIN_ENABLED:
                print(f"\nPERFORMANCE DEGRADATION DETECTED!")
                print(f"   Reasons:")
                for reason in retraining_reasons:
                    print(f"      • {reason}")
                
                print(f"\nTRIGGERING AUTOMATED RETRAINING...")
                
                # Create a retraining trigger run
                alert_run = wandb.init(
                    project=PROJECT,
                    job_type="automated-retraining-trigger",
                    name=f"retrain-trigger-{datetime.now().strftime('%Y%m%d-%H%M%S')}",
                    tags=["retraining", "automated", "triggered"],
                    config={
                        'trigger_reason': ', '.join(retraining_reasons),
                        'avg_confidence': avg_confidence,
                        'avg_drift': avg_drift,
                        'avg_latency': avg_latency,
                        'threshold_confidence': CONFIDENCE_THRESHOLD,
                        'threshold_drift': DRIFT_THRESHOLD,
                        'monitoring_run': latest_monitor_run.name
                    }
                )
                
                # Log the trigger event
                wandb.log({
                    'retraining_triggered': 1,
                    'avg_confidence': avg_confidence,
                    'avg_drift': avg_drift,
                    'timestamp': datetime.now().timestamp()
                })
                
                # Send alert to team
                wandb.alert(
                    title="Automated Retraining Triggered",
                    text=f"""Model performance has degraded and requires retraining.
                    
**Performance Issues:**
{chr(10).join(['• ' + r for r in retraining_reasons])}

**Metrics:**
• Average Confidence: {avg_confidence:.4f}
• Average Drift: {avg_drift:.4f}
• Average Latency: {avg_latency:.2f}ms

**Action:** A new hyperparameter sweep should be launched to find a better model.

**Monitoring Run:** {latest_monitor_run.name}
**Trigger Time:** {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
""",
                    level=wandb.AlertLevel.WARN
                )
                
                print(f"\nRetraining trigger logged to W&B")
                print(f"   Run URL: {alert_run.url}")
                print(f"   Alert sent to team")
                
                # --- Option to Launch New Sweep Automatically ---
                print(f"\nNext Steps:")
                print(f"   1. A new hyperparameter sweep should be launched")
                print(f"   2. You can automate this by uncommenting the code below")
                
                # UNCOMMENT TO ENABLE AUTOMATIC SWEEP LAUNCH
                """
                print(f"\nLaunching new SSL sweep...")
                
                # Use the SSL sweep config from earlier
                new_sweep_id = wandb.sweep(ssl_sweep_config, project=PROJECT)
                print(f"   ✓ New sweep created: {new_sweep_id}")
                
                # Optionally run some agents automatically
                # wandb.agent(new_sweep_id, train_ssl, count=10)
                """
                
                alert_run.finish()
                
            elif needs_retraining and not AUTO_RETRAIN_ENABLED:
                print(f"\nRETRAINING RECOMMENDED BUT AUTO-RETRAIN IS DISABLED")
                print(f"   Reasons:")
                for reason in retraining_reasons:
                    print(f"      • {reason}")
                print(f"\n   Enable automatic retraining by setting AUTO_RETRAIN_ENABLED = True")
                
            else:
                print(f"\nMODEL PERFORMANCE IS HEALTHY")
                print(f"   No retraining needed at this time")
                
        else:
            print("No metrics found in monitoring run history")
            
    except Exception as e:
        print(f"Error analyzing metrics: {e}")
        
else:
    print("\nSkipping: No monitoring data available")
    print("   Run the production monitoring script first (Phase 5)")

print("Automated retraining pipeline completed")
# Out:
# Error in callback <bound method _WandbInit._pre_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 7928b7dba8d0, raw_cell="import wandb
# import numpy as np
# from datetime impo.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X44sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:596, in _WandbInit._pre_run_cell_hook(self, *args, **kwargs)
#     594 if self.backend.interface is not None:
#     595     self._logger.info("pausing backend")
# --> 596     self.backend.interface.publish_pause()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:803, in InterfaceBase.publish_pause(self)
#     801 def publish_pause(self) -> None:
#     802     pause = pb.PauseRequest()
# --> 803     self._publish_pause(pause)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:330, in InterfaceShared._publish_pause(self, pause)
#     328 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     329     rec = self._make_request(pause=pause)
# --> 330     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
# ================================================================================
# 🔄 AUTOMATED RETRAINING PIPELINE
# ================================================================================
#
# 📡 Connecting to Weights & Biases API...
# ✓ Connected to entity: l-benhammadi-esi
# ✓ Project: QSAR_MLOPS
#
# 📊 Fetching monitoring runs (last 7 days)...
# ✓ Found 1 monitoring runs
#
# 🔍 Analyzing model performance...
#    Latest run: production-monitoring-20260124-180350
#    Created at: 2026-01-24T16:27:18Z
#
# 📈 Performance Metrics:
#    Average Confidence: 0.8373
#    Average Drift Score: 0.1516
#    Average Latency: 30.84ms
#    Total Predictions: 100
#
# 🎯 Evaluating against thresholds...
#    Confidence threshold: 0.7
#    Drift threshold: 0.25
#    ✓ Confidence is healthy
#    ✓ Drift is within acceptable range
#
# ✅ MODEL PERFORMANCE IS HEALTHY
#    No retraining needed at this time
#
# ================================================================================
# ✅ Automated retraining pipeline completed
# ================================================================================
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7928aedaed10>> (for post_run_cell), with arguments args (<ExecutionResult object at 7928b1a38cd0, execution_count=24 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7928b7dba8d0, raw_cell="import wandb
# import numpy as np
# from datetime impo.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/lokmane/Desktop/mini_projet/notebooks/tox21/tox21_mlops_life_cycle.ipynb#X44sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File ~/anaconda3/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
